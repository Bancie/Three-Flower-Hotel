# %% [markdown]
# # Mô tả hệ thống Hotel Management
#
# ## 1. Tiếp nhận yêu cầu đặt phòng
# - Khách sạn cung cấp các dịch vụ lưu trú và dịch vụ đi kèm (phòng, ăn uống, giặt ủi, spa, …) theo yêu cầu đặt phòng của khách hàng.
# - Khi khách hàng gửi yêu cầu đặt phòng, nhân viên lễ tân kiểm tra:
#   - Loại phòng
#   - Thời gian lưu trú
#   - Số lượng phòng
#   - Các dịch vụ đi kèm
# - Nếu khách sạn không có đủ phòng hoặc không cung cấp một số dịch vụ theo yêu cầu, lễ tân sẽ từ chối đặt phòng.
# - Nếu có thể đáp ứng, lễ tân tiếp nhận đơn đặt phòng và lưu thông tin khách hàng (tạo hồ sơ mới nếu là khách mới).
#
# ## 2. Kiểm tra tình trạng phòng và thanh toán
# - Sau khi tiếp nhận yêu cầu, lễ tân:
#   - Kiểm tra tình trạng phòng trống trong hệ thống
#   - Đối chiếu lịch đặt phòng
#   - Xác minh tình trạng thanh toán hoặc công nợ của khách (đối với khách quen hoặc khách doanh nghiệp)
# - Nếu:
#   - Không đủ phòng trong thời gian yêu cầu, hoặc
#   - Khách hàng còn nợ các khoản thanh toán trước đó
#   → Lễ tân từ chối xác nhận đặt phòng.
# - Nếu không có vấn đề, lễ tân lập phiếu xác nhận đặt phòng (booking) dựa trên yêu cầu của khách hàng.
#
# ## 3. Thanh toán và nhận phòng
# - Khách hàng sử dụng phiếu xác nhận đặt phòng để thanh toán tại bộ phận tài chính / thu ngân.
# - Sau khi khách hàng thanh toán đầy đủ hoặc đặt cọc theo quy định:
#   - Bộ phận tài chính xác nhận thanh toán
#   - Gửi thông tin cho lễ tân và bộ phận buồng phòng
# - Khi khách đến khách sạn:
#   - Lễ tân làm thủ tục check-in
#   - Bàn giao phòng cho khách
#
# ## 4. Sử dụng dịch vụ và trả phòng
# - Trong thời gian lưu trú, các dịch vụ phát sinh của khách hàng được ghi nhận vào hóa đơn.
# - Khi khách check-out:
#   - Khách hàng nhận hóa đơn tổng hợp
#   - Hoàn tất quá trình sử dụng dịch vụ tại khách sạn

# %% [markdown]
# # KẾ HOẠCH DỰ ÁN
# ## Hệ thống Thông tin Quản lý Khách sạn
#
# ## 1. Xác định và chọn lựa dự án
# - **Tên dự án:** Hệ thống thông tin quản lý khách sạn
# - **Mục tiêu:** Tin học hóa công tác quản lý phòng, khách hàng, dịch vụ và thanh toán trong khách sạn
# - **Lý do chọn dự án:**
#   - Phù hợp thực tế
#   - Nghiệp vụ rõ ràng
#   - Dễ áp dụng mô hình HTTT và CSDL
#
# **Thời gian:** Tuần 1
# **Người thực hiện:** Cả nhóm
#
# ## 2. Lập kế hoạch
# - Xác định phạm vi hệ thống
# - Lập danh sách chức năng chính
# - Phân công nhiệm vụ cho các thành viên
# - Xây dựng tiến độ thực hiện
#
# **Thời gian:** Tuần 1
# **Người thực hiện:** Trưởng nhóm + cả nhóm
#
# ## 3. Phân tích
# - Phân tích hiện trạng quản lý khách sạn
# - Xác định yêu cầu chức năng
# - Xác định yêu cầu dữ liệu
# - Mô tả nghiệp vụ (đặt phòng, check-in, check-out, thanh toán…)
#
# **Thời gian:** Tuần 2
# **Người thực hiện:** Nhóm phân tích
#
# ## 4. Thiết kế hệ thống
#
# ### 4.1 Thiết kế dữ liệu
# - Xác định các thực thể: Phòng, Khách hàng, Đặt phòng, Dịch vụ, Hóa đơn, Nhân viên
# - Thiết kế ERD
# - Chuyển ERD sang RDM
#
# **Thời gian:** Tuần 3
# **Người thực hiện:** Thành viên phụ trách CSDL
#
# ### 4.2 Thiết kế xử lý
# - Thiết kế các chức năng:
#   - Quản lý phòng
#   - Quản lý khách hàng
#   - Đặt phòng
#   - Thanh toán
# - Thiết kế luồng xử lý nghiệp vụ
#
# **Thời gian:** Tuần 3
# **Người thực hiện:** Nhóm thiết kế
#
# ### 4.3 Thiết kế giao diện
# - Thiết kế giao diện lễ tân
# - Thiết kế giao diện quản lý
# - Thiết kế các màn hình chính
#
# **Thời gian:** Tuần 4
# **Người thực hiện:** Thành viên phụ trách giao diện
#
# ## 5. Cài đặt
# - Xây dựng cơ sở dữ liệu MySQL
# - Lập trình backend (Python)
# - Lập trình frontend (React)
# - Kết nối frontend – backend
#
# **Thời gian:** Tuần 5–6
# **Người thực hiện:** Nhóm lập trình
#
# ## 6. Thử nghiệm
# - Kiểm thử các chức năng
# - Kiểm tra tính đúng đắn của dữ liệu
# - Sửa lỗi và hoàn thiện hệ thống
#
# **Thời gian:** Tuần 7
# **Người thực hiện:** Cả nhóm
#
# ## 7. Bảng tổng hợp kế hoạch
#
# | STT | Công việc | Thời gian bắt đầu | Thời gian kết thúc | Người thực hiện |
# |-----|----------|-------------------|--------------------|-----------------|
# | 1 | Xác định & chọn dự án | Tuần 1 | Tuần 1 | Cả nhóm |
# | 2 | Lập kế hoạch | Tuần 1 | Tuần 1 | Trưởng nhóm |
# | 3 | Phân tích | Tuần 2 | Tuần 2 | Nhóm phân tích |
# | 4 | Thiết kế dữ liệu | Tuần 3 | Tuần 3 | TV CSDL |
# | 5 | Thiết kế xử lý | Tuần 3 | Tuần 3 | Nhóm |
# | 6 | Thiết kế giao diện | Tuần 4 | Tuần 4 | TV giao diện |
# | 7 | Cài đặt | Tuần 5 | Tuần 6 | Nhóm lập trình |
# | 8 | Thử nghiệm | Tuần 7 | Tuần 7 | Cả nhóm |

# %% [markdown]
# # ERD - RDM
#
# ![](/Users/chibangnguyen/ayai/Three-Flower-Hotel/rdm.png){ width=350px }

# %% [markdown]
# # DFD mức 0
#
# ![Context Diagram - Hotel System](Context%20Diagram%20-%20Hotel%20System.png)

# %% [markdown]
# # DFD mức 1
#
# ![Context Diagram - Hotel System](/Users/chibangnguyen/ayai/Three-Flower-Hotel/dfd1.png)
